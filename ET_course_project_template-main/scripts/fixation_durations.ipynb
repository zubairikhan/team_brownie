# %%
import pandas as pd
import seaborn as sns

# %%
screen_width_pix = 1920
screen_height_pix = 1080

# %%
subjects_to_include = "data/subject_files.txt"
resumes_to_include = "data/resume_names.txt"

# %%
subjects_data = []  # contains raw eye-tracking data for each subject
times_subjects = []  # list of dataframes. each dataframe contains times spent per block per resume for each subject
times_subjects_norm = []  # list of dataframes. each dataframe contains times spent per block per resume for each subject, normalized
all_resumes = []   # resume names
subject_files = []

# %%
with open(subjects_to_include, 'r') as file:
    lines = file.readlines()
    for line in lines:
        subject_files.append(line.strip())
        
print(subject_files)
# Out:
# ['data/subjects_tsv/subject-1.tsv', 'data/subjects_tsv/subject-2.tsv', 'data/subjects_tsv/subject-3.tsv', 'data/subjects_tsv/subject-4.tsv', 'data/subjects_tsv/subject-5.tsv', 'data/subjects_tsv/subject-6.tsv', 'data/subjects_tsv/subject-7.tsv', 'data/subjects_tsv/subject-8.tsv', 'data/subjects_tsv/subject-9.tsv', 'data/subjects_tsv/subject-10.tsv', 'data/subjects_tsv/subject-12.tsv']

# %%
with open(resumes_to_include, 'r') as file:
    lines = file.readlines()
    for line in lines:
        all_resumes.append(line.strip())
        
print(all_resumes)
# Out:
# ['QUALIFIED_NOPIC_ GOODSORT_HANNAH.PNG', 'QUALIFIED_PIC_ GOODSORT_HANNAH.PNG', 'QUALIFIED_PIC_ GOODSORT_AISHA.PNG', 'QUALIFIED_NOPIC_ GOODSORT_AISHA.PNG', 'QUALIFIED_NOPIC_BADSORT_DAVID.PNG', 'QUALIFIED_PIC_BADSORT_DAVID.PNG', 'UNQUALIFIED_PIC_BADSORT_TIAN.PNG', 'UNQUALIFIED_NOPIC_BADSORT_TIAN.PNG', 'QUALIFIED_PIC_BADSORT_VIKTOR.PNG', 'QUALIFIED_NOPIC_BADSORT_VIKTOR.PNG', 'QUALIFIED_PIC_BADSORT_RAHUL.PNG', 'QUALIFIED_NOPIC_BADSORT_RAHUL.PNG', 'QUALIFIED_PIC_GOODSORT_EMILIA.PNG', 'QUALIFIED_NOPIC_GOODSORT_EMILIA.PNG', 'UNQUALIFIED_NOPIC_GOODSORT_LEA.PNG', 'UNQUALIFIED_PIC_GOODSORT_LEA.PNG', 'UNQUALIFIED_NOPIC_ BADSORT_MARIA.PNG', 'UNQUALIFIED_PIC_ BADSORT_MARIA.PNG', 'UNQUALIFIED_PIC_ BADSORT_LEILA.PNG', 'UNQUALIFIED_NOPIC_ BADSORT_LEILA.PNG', 'UNQUALIFIED_NOPIC_GOODSORT_KARE.PNG', 'UNQUALIFIED_PIC_GOODSORT_KARE.PNG', 'UNQUALIFIED_NOPIC_GOODSORT_HANS.PNG', 'UNQUALIFIED_PIC_GOODSORT_HANS.PNG']

# %%
def filter_keys(original_dict, allowed_keys):
    filtered_dict = {key: value for key, value in original_dict.items() if key in allowed_keys}
    return filtered_dict

# %%
# pixel coordinates for areas of interest for each resume. coordinates correspond to 1920*1080 resolution

aoi_all = {
    "QUALIFIED_PIC_GOODSORT_EMILIA.PNG": {
        "name" : [(605,39), (980,245)],
        "picture" : [(995,39), (1314,245)],
        "experience" : [(605,245), (980,1040)],
        "languages" : [(995,245), (1314,385)],
        "education" : [(995,385), (1314,610)],
        "skills" : [(995,610), (1314,770)],
        "hobbies" : [(995,870), (1314,1040)],
        "soft_skills" : [(995,770), (1314,870)]
    },
    "QUALIFIED_NOPIC_GOODSORT_EMILIA.PNG": {
        "name" : [(605,39), (980,245)],
        "picture" : [(-1,-1), (-1,-1)],
        "experience" : [(605,245), (980,1040)],
        "languages" : [(995,245), (1314,385)],
        "education" : [(995,385), (1314,610)],
        "skills" : [(995,610), (1314,770)],
        "hobbies" : [(995,870), (1314,1040)],
        "soft_skills" : [(995,770), (1314,870)]
    },
    "QUALIFIED_NOPIC_BADSORT_VIKTOR.PNG": {
        "name" : [(605,39), (952,243)],
        "picture" : [(-1,-1), (-1,-1)],
        "experience" : [(937,405), (1314,1040)],
        "languages" : [(605,577), (937,745)],
        "soft_skills" : [(605,265), (937,402)],
        "skills" : [(605,405), (937,575)],
        "education" : [(605,745), (937,1040)],
        "hobbies" : [(937,265), (1314,402)]
    },
    "QUALIFIED_PIC_BADSORT_VIKTOR.PNG": {
        "name" : [(605,39), (952,243)],
        "picture" : [(937,39), (1314,243)],
        "experience" : [(937,405), (1314,1040)],
        "languages" : [(605,577), (937,745)],
        "soft_skills" : [(605,265), (937,402)],
        "skills" : [(605,405), (937,575)],
        "education" : [(605,745), (937,1040)],
        "hobbies" : [(937,265), (1314,402)]
    },
    "UNQUALIFIED_NOPIC_GOODSORT_KARE.PNG": {
        "name" : [(605,39), (944,243)],
        "picture" : [(-1,-1), (-1,-1)],
        "experience" : [(605,255), (944,797)],
        "languages" : [(950,607), (1040,870)],
        "soft_skills" : [(-1,-1), (-1,-1)],
        "skills" : [(950,423), (1040,605)],
        "education" : [(950,255), (1040,420)],
        "hobbies" : [(605,805), (944,980)]
    },
    "UNQUALIFIED_PIC_GOODSORT_KARE.PNG": {
        "name" : [(605,39), (944,243)],
        "picture" : [(950,39), (1040,243)],
        "experience" : [(605,255), (944,797)],
        "languages" : [(950,607), (1040,870)],
        "soft_skills" : [(-1,-1), (-1,-1)],
        "skills" : [(950,423), (1040,605)],
        "education" : [(950,255), (1040,420)],
        "hobbies" : [(605,805), (944,980)]
    },
    "UNQUALIFIED_PIC_GOODSORT_HANS.PNG": {
        "name" : [(605,39), (959,258)],
        "picture" : [(958,39), (1314,258)],
        "experience" : [(605,405),(964,955)],
        "languages" : [(958,257),((1314,404))],
        "soft_skills" : [(958,551),(1314,712)],
        "skills" : [(958,404),(1314,547)],
        "education" : [(605,258),(961,404)],
        "hobbies" : [(958,713),(1314,900)]
    },
    "UNQUALIFIED_NOPIC_GOODSORT_HANS.PNG": {
        "name" : [(605,39), (959,258)],
        "picture" : [(-1,-1), (-1,-1)],
        "experience" : [(605,405),(964,955)],
        "languages" : [(958,257),((1314,404))],
        "soft_skills" : [(958,551),(1314,712)],
        "skills" : [(958,404),(1314,547)],
        "education" : [(605,258),(961,404)],
        "hobbies" : [(958,713),(1314,900)]
    },
    "UNQUALIFIED_NOPIC_ BADSORT_MARIA.PNG": {
        "name" : [(605,39),(954,249)],
        "picture" : [(-1,-1),(-1,-1)],
        "experience" : [(605,254),(954,885)],
        "languages" : [(954,559),(1314,728)],
        "soft_skills" : [(-1,-1),(-1,-1)],
        "skills" : [(954,405),(1314,554)],
        "education" : [(954,249),(1314,401)],
        "hobbies" : [(954,733),(1314,885)]
    },
    "UNQUALIFIED_PIC_ BADSORT_MARIA.PNG": {
        "name" : [(605,39),(954,249)],
        "picture" : [(954,39),(1314,249)],
        "experience" : [(605,254),(954,885)],
        "languages" : [(954,559),(1314,728)],
        "soft_skills" : [(-1,-1),(-1,-1)],
        "skills" : [(954,405),(1314,554)],
        "education" : [(954,249),(1314,401)],
        "hobbies" : [(954,733),(1314,885)]
    },
    "UNQUALIFIED_NOPIC_GOODSORT_LEA.PNG": {
        "name" : [(605,39),(945,250)],
        "picture" : [(-1,-1),(-1,-1)],
        "experience" : [(945,250),(1314,738)],
        "languages" : [(605,734),(945,910)],
        "soft_skills" : [(605,415),(945,570)],
        "skills" : [(605,574),(945,730)],
        "education" : [(945,742),(1314,990)],
        "hobbies" : [(605,255),(945,410)]
    },
    "UNQUALIFIED_PIC_GOODSORT_LEA.PNG": {
        "name" : [(605,39),(945,250)],
        "picture" : [(945,39),(1314,250)],
        "experience" : [(945,250),(1314,738)],
        "languages" : [(605,734),(945,910)],
        "soft_skills" : [(605,415),(945,570)],
        "skills" : [(605,574),(945,730)],
        "education" : [(945,742),(1314,990)],
        "hobbies" : [(605,255),(945,410)]
    },
    "UNQUALIFIED_PIC_BADSORT_TIAN.PNG": {
        "name" : [(605,39),(930,250)],
        "picture" : [(930,39),(1314,248)],
        "experience" : [(930,252),(1314,740)],
        "languages" : [(605,423),(930,650)],
        "soft_skills" : [(605,809),(930,970)],
        "skills" : [(605,654),(930,805)],
        "education" : [(605,43),(930,419)],
        "hobbies" : [(930,744),(1314,890)]
    },
    "UNQUALIFIED_NOPIC_BADSORT_TIAN.PNG": {
        "name" : [(605,39),(930,250)],
        "picture" : [(-1,-1),(-1,-1)],
        "experience" : [(930,252),(1314,740)],
        "languages" : [(605,423),(930,650)],
        "soft_skills" : [(605,809),(930,970)],
        "skills" : [(605,654),(930,805)],
        "education" : [(605,43),(930,419)],
        "hobbies" : [(930,744),(1314,890)]
    },
    "UNQUALIFIED_PIC_ BADSORT_LEILA.PNG": {
        "name" : [(605,39),(934,248)],
        "picture" : [(938,39),(1314,248)],
        "experience" : [(938,412),(1314,984)],
        "languages" : [(938,252),(1314,408)],
        "soft_skills" : [(605,386),(934,634)],
        "skills" : [(605,638),(934,736)],
        "education" : [(605,740),(934,945)],
        "hobbies" : [(605,252),(934,382)]
    },
    "UNQUALIFIED_NOPIC_ BADSORT_LEILA.PNG": {
        "name" : [(605,39),(934,248)],
        "picture" : [(-1,-1),(-1,-1)],
        "experience" : [(938,412),(1314,984)],
        "languages" : [(938,252),(1314,408)],
        "soft_skills" : [(605,386),(934,634)],
        "skills" : [(605,638),(934,736)],
        "education" : [(605,740),(934,945)],
        "hobbies" : [(605,252),(934,382)]
    },
    "QUALIFIED_NOPIC_ GOODSORT_HANNAH.PNG": {
        "name" : [(605,39),(995,240)],
        "picture" : [(-1,-1),(-1,-1)],
        "experience" : [(915,245),(1314,965)],
        "languages" : [(605,499),(910,655)],
        "soft_skills" : [(605,829),(910,965)],
        "skills" : [(605,659),(910,825)],
        "education" : [(605,244),(910,495)],
        "hobbies" : [(-1,-1),(-1,-1)]
    },
    "QUALIFIED_PIC_ GOODSORT_HANNAH.PNG": {
        "name" : [(605,39),(995,240)],
        "picture" : [(996,39),(1314,240)],
        "experience" : [(915,245),(1314,965)],
        "languages" : [(605,499),(910,655)],
        "soft_skills" : [(605,829),(910,965)],
        "skills" : [(605,659),(910,825)],
        "education" : [(605,244),(910,495)],
        "hobbies" : [(-1,-1),(-1,-1)]
    },
    "QUALIFIED_PIC_ GOODSORT_AISHA.PNG": {
        "name" : [(605,39),(1015,259)],
        "picture" : [(1020,39),(1314,260)],
        "experience" : [(910,384),(1314,1040)],
        "languages" : [(605,581),(906,695)],
        "soft_skills" : [(605,264),(906,418)],
        "skills" : [(605,422),(906,577)],
        "education" : [(605,699),(906,1040)],
        "hobbies" : [(910,264),(1314,380)]
    },
    "QUALIFIED_NOPIC_ GOODSORT_AISHA.PNG": {
        "name" : [(605,39),(1015,259)],
        "picture" : [(-1,-1),(-1,-1)],
        "experience" : [(910,384),(1314,1040)],
        "languages" : [(605,581),(906,695)],
        "soft_skills" : [(605,264),(906,418)],
        "skills" : [(605,422),(906,577)],
        "education" : [(605,699),(906,1040)],
        "hobbies" : [(910,264),(1314,380)]
    },
    "QUALIFIED_PIC_BADSORT_RAHUL.PNG": {
        "name" : [(605,39),(946,232)],
        "picture" : [(950,39),(1314,240)],
        "experience" : [(605,236),(946,895)],
        "languages" : [(950,468),(1314,653)],
        "soft_skills" : [(950,808),(1314,956)],
        "skills" : [(950,657),(1314,804)],
        "education" : [(950,244),(1314,464)],
        "hobbies" : [(-1,-1),(-1,-1)]
    },
    "QUALIFIED_NOPIC_BADSORT_RAHUL.PNG": {
        "name" : [(605,39),(946,232)],
        "picture" : [(-1,-1),(-1,-1)],
        "experience" : [(605,236),(946,895)],
        "languages" : [(950,468),(1314,653)],
        "soft_skills" : [(950,808),(1314,956)],
        "skills" : [(950,657),(1314,804)],
        "education" : [(950,244),(1314,464)],
        "hobbies" : [(-1,-1),(-1,-1)]
    },
    "QUALIFIED_NOPIC_BADSORT_DAVID.PNG": {
        "name" : [(605,39),(930,238)],
        "picture" : [(-1,-1),(-1,-1)],
        "experience" : [(930,242),(1314,995)],
        "languages" : [(605,863),(930,995)],
        "soft_skills" : [(605,242),(930,506)],
        "skills" : [(605,510),(930,673)],
        "education" : [(605,676),(930,860)],
        "hobbies" : [(-1,-1),(-1,-1)]
    },
    "QUALIFIED_PIC_BADSORT_DAVID.PNG": {
        "name" : [(605,39),(930,238)],
        "picture" : [(930,39),(1314,238)],
        "experience" : [(930,242),(1314,995)],
        "languages" : [(605,863),(930,995)],
        "soft_skills" : [(605,242),(930,506)],
        "skills" : [(605,510),(930,673)],
        "education" : [(605,676),(930,860)],
        "hobbies" : [(-1,-1),(-1,-1)]
    }
}

# %%
for file in subject_files:
    df = pd.read_csv(file, sep='\t')
    
    #using only required fields
    df = df[['CNT', 'TIME', 'TIME_TICK', 'FPOGX', 'FPOGY', 'FPOGS', 'FPOGD', 'FPOGID', 'FPOGV', 'USER']]
    subjects_data.append(df)
# Out:
# /var/folders/ps/w69mhq794zq0cpvzb8t769l80000gn/T/ipykernel_87424/4199832748.py:2: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep='\t')
# /var/folders/ps/w69mhq794zq0cpvzb8t769l80000gn/T/ipykernel_87424/4199832748.py:2: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep='\t')

# %%
# find resumes displayed to the participant with
# indexes for splitting samples into separate dataframes for each resume

def find_displayed_resumes_and_indexes(all_resumes, df):
    disp_resumes = []
    indexes = []
    for resume in all_resumes:
        
        start_row = df[df['USER'] == resume + ' DISPLAYED']
        end_row = df[df['USER'] == resume + ' HIDDEN']
        if (len(start_row) == 0 or len(end_row)==0):
            continue
        start_index = start_row.index[0]
        end_index = end_row.index[0]
        indexes.append((start_index, end_index))
        disp_resumes.append(resume)
    return indexes, disp_resumes

# %%
# grouping samples into fixations:
# eliminate non valid samples by keeping only those with FPOGV == 1
# group by fixation ID
# take fpogx and fpogy values of last sample in the fixation for fixation position. do the same for fixation duration

def group_samples_into_fixations(resume_data_samples, fixations_df):
    for df in resume_data_samples:
        df = df[df['FPOGV'] == 1]
        df = df.groupby('FPOGID').agg({
        'FPOGX' : 'last',
        'FPOGY' : 'last',
        'FPOGD' : 'last'
    }).reset_index()
        fixations_df.append(df)

# %%
def normalize_times(times):
    total_time = times.get("total_time_on_resume")
    normalized_data = {}
    
    for key, value in times.items():
        normalized_data[key] = value / total_time  # Keep total_time_on_resume as it is

    return normalized_data

# %%
def contains_picture(resume_name):
    if 'NOPIC' in resume_name:
        return False
    
    return True

# %%
for subject_data in subjects_data:
    
    
    # data structure to store amount of time spent fixation on each area for each resume

    times_all = {
        "QUALIFIED_PIC_GOODSORT_EMILIA.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "QUALIFIED_NOPIC_GOODSORT_EMILIA.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "QUALIFIED_NOPIC_BADSORT_VIKTOR.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "QUALIFIED_PIC_BADSORT_VIKTOR.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "UNQUALIFIED_NOPIC_GOODSORT_KARE.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "UNQUALIFIED_PIC_GOODSORT_KARE.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "UNQUALIFIED_PIC_GOODSORT_HANS.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "UNQUALIFIED_NOPIC_GOODSORT_HANS.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "UNQUALIFIED_NOPIC_ BADSORT_MARIA.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "UNQUALIFIED_PIC_ BADSORT_MARIA.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "UNQUALIFIED_NOPIC_GOODSORT_LEA.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "UNQUALIFIED_PIC_GOODSORT_LEA.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "UNQUALIFIED_PIC_BADSORT_TIAN.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "UNQUALIFIED_NOPIC_BADSORT_TIAN.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "UNQUALIFIED_PIC_ BADSORT_LEILA.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "UNQUALIFIED_NOPIC_ BADSORT_LEILA.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "QUALIFIED_NOPIC_ GOODSORT_HANNAH.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "QUALIFIED_PIC_ GOODSORT_HANNAH.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "QUALIFIED_PIC_ GOODSORT_AISHA.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "QUALIFIED_NOPIC_ GOODSORT_AISHA.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "QUALIFIED_PIC_BADSORT_RAHUL.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "QUALIFIED_NOPIC_BADSORT_RAHUL.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "QUALIFIED_NOPIC_BADSORT_DAVID.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        },
        "QUALIFIED_PIC_BADSORT_DAVID.PNG": {
            "name" : 0,
            "picture" : 0,
            "experience" : 0,
            "languages" : 0,
            "education" : 0,
            "skills" : 0,
            "hobbies" : 0,
            "soft_skills" : 0,
            "untagged": 0,
            "total_time_on_resume" : 0
        }
    }
    
    indexes, resumes = find_displayed_resumes_and_indexes(all_resumes, subject_data)
    
    aoi = filter_keys(aoi_all, resumes)
    times = filter_keys(times_all, resumes)
    
    times_normalized = times.copy()
    
    total_time_per_resume = []
    
    resume_data_fixations = []  # list of dataframes. contains fixations data for each resume.
    
    
    #splitting samples into separate dataframes for each resume
    resume_data_samples = []
    
    for i in range(len(indexes)):
        total_time = subject_data.at[indexes[i][1],"TIME"] - subject_data.at[indexes[i][0],"TIME"]
        total_time_per_resume.append(total_time)
        resume_data_samples.append(subject_data.loc[indexes[i][0] : indexes[i][1]])
        
    group_samples_into_fixations(resume_data_samples, resume_data_fixations)
    
    
    # calculation for time spent fixating on each area in each resume
    
    for i in range(len(resume_data_samples)):
        time_text_area = 0
        time_pic_area = 0
        
        current_resume = resumes[i]
        areas = aoi[current_resume]
        
        fixations = resume_data_fixations[i]
        for j in range(len(fixations)):
            fixation = fixations.loc[j]
            fixation_tagged = False
            
            x_pixel = fixation['FPOGX'] * screen_width_pix #1920
            y_pixel = fixation['FPOGY'] * screen_height_pix #1080
            
            fixation_duration = fixation['FPOGD']
            
            times[current_resume]['total_time_on_resume'] += fixation_duration
            times_normalized[current_resume]['total_time_on_resume'] += fixation_duration
            
            for area_name, area_coord in areas.items():
                
                area_start = area_coord[0]
                area_end = area_coord[1]
                
                if (x_pixel > area_start[0] and x_pixel < area_end[0] and
                    y_pixel > area_start[1] and y_pixel < area_end[1]):
                    
                    
                    #if text area, add fpogd to time_text else time_pic
                    if (area_name == 'picture'):
                        time_pic_area += fixation_duration
                    else:
                        time_text_area += fixation_duration
                    
                    times[current_resume][area_name] += fixation_duration
                    times_normalized[current_resume][area_name] += fixation_duration
                    fixation_tagged = True
                    break
                    
            # if not assigned to any area
            if (fixation_tagged == False):
                times[current_resume]['untagged'] += fixation_duration
                times_normalized[current_resume]['untagged'] += fixation_duration
                
        times_normalized[current_resume] = normalize_times(times_normalized[current_resume])
        
    times_subjects.append(times)
    times_subjects_norm.append(times_normalized)

# %%
participant_time_spent_pic_and_text_2 = pd.DataFrame()

participant_time_spent_pic_and_text_2['Part_idx'] = []
participant_time_spent_pic_and_text_2['resume'] = []
participant_time_spent_pic_and_text_2['contains_pic'] = []
participant_time_spent_pic_and_text_2['time_text'] = []
participant_time_spent_pic_and_text_2['time_pic'] = []

rows = []

# %%
for i in range(len(times_subjects)):
    participant_idx = i
    for resume_name, area_times in times_subjects[i].items():
        time_pic_area = area_times['picture']
        time_text_area = area_times['total_time_on_resume'] - time_pic_area
        
        rows.append({
            'Part_idx': participant_idx,
            'resume': resume_name,
            'contains_pic': contains_picture(resume_name),
            'time_text': time_text_area,
            'time_pic': time_pic_area
        })
        

participant_time_spent_pic_and_text_2 = pd.concat([participant_time_spent_pic_and_text_2, pd.DataFrame(rows)], ignore_index=True)

# %%
participant_time_spent_pic_and_text_2.to_csv('output/output.csv', index=False)

# %%
def mean_block_times(block_times, num_of_resumes):
    mean_block_times = {}
    print(num_of_resumes)
    
    for key, value in block_times.items():
        mean_block_times[key] = value / num_of_resumes
        
    return mean_block_times

# %%
def processing_times(times_subjects, y_axis_label):
    block_times_resumes_with_pic = []
    block_times_resumes_without_pic = []
    
    for subject_resumes in times_subjects:
        resume_names = subject_resumes.keys()
    
        for resume_name in resume_names:
            if contains_picture(resume_name):
                block_times_resumes_with_pic.append(subject_resumes[resume_name])
            else:
                block_times_resumes_without_pic.append(subject_resumes[resume_name])
            
    block_times_with_pic = {}
    block_times_without_pic = {}

    for resume_times in block_times_resumes_with_pic:
        for key, value in resume_times.items():
            if key in block_times_with_pic:
                block_times_with_pic[key] += value
            else:
                block_times_with_pic[key] = value

    for resume in block_times_resumes_without_pic:
        for key, value in resume.items():
            if key in block_times_without_pic:
                block_times_without_pic[key] += value
            else:
                block_times_without_pic[key] = value
                
    mean_scaled_block_duration_pic = mean_block_times(block_times_with_pic, len(block_times_resumes_with_pic)) 
    mean_scaled_block_duration_nopic = mean_block_times(block_times_without_pic, len(block_times_resumes_without_pic)) 
                
    blocks = []
    relative_times = []
    pictures = []

    for key, value in mean_scaled_block_duration_pic.items():
        blocks.append(key)
        relative_times.append(value)
        pictures.append("Yes")  

    for key, value in mean_scaled_block_duration_nopic.items():
        blocks.append(key)
        relative_times.append(value)
        pictures.append("No")

    df = pd.DataFrame({
        'block': blocks,
        'time': relative_times,
        'picture': pictures
    })


    df = df[df['block'] != 'total_time_on_resume']
    
    sns.set_theme(style="whitegrid")

    g = sns.catplot(
        data=df, kind="bar",
        x="block", y="time", hue="picture", aspect = 2)

    g.set_axis_labels("Blocks", y_axis_label)

# %%
processing_times(times_subjects, "Mean fixation duration")
# Out:
# 66
# 65

# %%
processing_times(times_subjects_norm, "Mean fixation duration normalized")
# Out:
# 66
# 65

# %%
times_subjects
# Out:
# [{'QUALIFIED_PIC_GOODSORT_EMILIA.PNG': {'name': 0,
#    'picture': 0.26856,
#    'experience': 4.29688,
#    'languages': 0.2002,
#    'education': 0.22852,
#    'skills': 0,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 3.17282,
#    'total_time_on_resume': 8.166979999999999},
#   'QUALIFIED_NOPIC_BADSORT_VIKTOR.PNG': {'name': 1.6211,
#    'picture': 0,
#    'experience': 15.363300000000004,
#    'languages': 3.750000000000001,
#    'education': 3.0127,
#    'skills': 3.1074400000000004,
#    'hobbies': 0.26758,
#    'soft_skills': 2.0625,
#    'untagged': 1.17774,
#    'total_time_on_resume': 30.362359999999995},
#   'UNQUALIFIED_PIC_GOODSORT_KARE.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 0,
#    'languages': 5.784179999999999,
#    'education': 0,
#    'skills': 2.4511800000000004,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 1.8603200000000002,
#    'total_time_on_resume': 10.095679999999996},
#   'UNQUALIFIED_PIC_GOODSORT_HANS.PNG': {'name': 0,
#    'picture': 0.34864,
#    'experience': 0.30762,
#    'languages': 1.16602,
#    'education': 0,
#    'skills': 1.03126,
#    'hobbies': 0.44238,
#    'soft_skills': 3.6709000000000005,
#    'untagged': 0,
#    'total_time_on_resume': 6.966819999999999},
#   'UNQUALIFIED_PIC_ BADSORT_MARIA.PNG': {'name': 0.25488,
#    'picture': 0,
#    'experience': 10.715799999999998,
#    'languages': 0,
#    'education': 0.41406,
#    'skills': 0.80274,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 0.49512,
#    'total_time_on_resume': 12.682599999999997},
#   'UNQUALIFIED_NOPIC_GOODSORT_LEA.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 2.88088,
#    'languages': 0,
#    'education': 0,
#    'skills': 0,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 0,
#    'total_time_on_resume': 2.88088},
#   'UNQUALIFIED_NOPIC_BADSORT_TIAN.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 2.7871000000000006,
#    'languages': 2.7763600000000004,
#    'education': 1.2041000000000002,
#    'skills': 0.60156,
#    'hobbies': 0,
#    'soft_skills': 0.72364,
#    'untagged': 0,
#    'total_time_on_resume': 8.092759999999998},
#   'UNQUALIFIED_NOPIC_ BADSORT_LEILA.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 1.15236,
#    'languages': 3.027319999999999,
#    'education': 0,
#    'skills': 0,
#    'hobbies': 0.52246,
#    'soft_skills': 0.36132,
#    'untagged': 0,
#    'total_time_on_resume': 5.063460000000002},
#   'QUALIFIED_NOPIC_ GOODSORT_HANNAH.PNG': {'name': 3.171879999999999,
#    'picture': 0,
#    'experience': 3.53712,
#    'languages': 1.95118,
#    'education': 1.3681800000000002,
#    'skills': 2.74608,
#    'hobbies': 0,
#    'soft_skills': 1.5273399999999997,
#    'untagged': 0.91016,
#    'total_time_on_resume': 15.21194},
#   'QUALIFIED_PIC_ GOODSORT_AISHA.PNG': {'name': 1.25976,
#    'picture': 0.38868,
#    'experience': 8.1572,
#    'languages': 3.7245800000000004,
#    'education': 1.1523400000000001,
#    'skills': 2.5732199999999996,
#    'hobbies': 4.28716,
#    'soft_skills': 7.071279999999998,
#    'untagged': 1.15038,
#    'total_time_on_resume': 29.764599999999998},
#   'QUALIFIED_PIC_BADSORT_RAHUL.PNG': {'name': 0.87108,
#    'picture': 1.4589599999999998,
#    'experience': 14.26854,
#    'languages': 1.8613199999999996,
#    'education': 4.311540000000001,
#    'skills': 1.38084,
#    'hobbies': 0,
#    'soft_skills': 2.10256,
#    'untagged': 0.36426000000000003,
#    'total_time_on_resume': 26.619099999999996},
#   'QUALIFIED_NOPIC_BADSORT_DAVID.PNG': {'name': 0.6299,
#    'picture': 0,
#    'experience': 27.238299999999988,
#    'languages': 2.3300600000000005,
#    'education': 4.31544,
#    'skills': 3.30664,
#    'hobbies': 0,
#    'soft_skills': 0.34864,
#    'untagged': 1.5273399999999997,
#    'total_time_on_resume': 39.696319999999986}},
#  {'QUALIFIED_NOPIC_GOODSORT_EMILIA.PNG': {'name': 2.3671800000000003,
#    'picture': 0,
#    'experience': 23.105400000000017,
#    'languages': 0.9785200000000001,
#    'education': 4.255880000000001,
#    'skills': 4.597660000000001,
#    'hobbies': 1.12696,
#    'soft_skills': 0.86914,
#    'untagged': 1.2988399999999998,
#    'total_time_on_resume': 38.59958000000001},
#   'QUALIFIED_PIC_BADSORT_VIKTOR.PNG': {'name': 2.1835999999999998,
#    'picture': 0,
#    'experience': 27.11136,
#    'languages': 4.28514,
#    'education': 3.66796,
#    'skills': 6.162099999999999,
#    'hobbies': 3.5781000000000014,
#    'soft_skills': 2.8652400000000005,
#    'untagged': 0.9511800000000001,
#    'total_time_on_resume': 50.80467999999999},
#   'UNQUALIFIED_PIC_GOODSORT_KARE.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 23.63282000000001,
#    'languages': 2.14454,
#    'education': 0,
#    'skills': 0.4961,
#    'hobbies': 0.1621,
#    'soft_skills': 0,
#    'untagged': 3.2695399999999992,
#    'total_time_on_resume': 29.705100000000016},
#   'UNQUALIFIED_NOPIC_GOODSORT_HANS.PNG': {'name': 1.8750000000000002,
#    'picture': 0,
#    'experience': 10.24806,
#    'languages': 0.91016,
#    'education': 2.74612,
#    'skills': 2.82422,
#    'hobbies': 2.29102,
#    'soft_skills': 1.21874,
#    'untagged': 0.10548,
#    'total_time_on_resume': 22.218799999999998},
#   'UNQUALIFIED_PIC_ BADSORT_MARIA.PNG': {'name': 0.9375,
#    'picture': 0,
#    'experience': 6.929679999999999,
#    'languages': 2.14454,
#    'education': 4.3164,
#    'skills': 4.058599999999999,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 2.5585999999999993,
#    'total_time_on_resume': 20.94532},
#   'UNQUALIFIED_PIC_GOODSORT_LEA.PNG': {'name': 3.72072,
#    'picture': 1.59568,
#    'experience': 6.3671999999999995,
#    'languages': 1.8749999999999998,
#    'education': 0.48242,
#    'skills': 0.88476,
#    'hobbies': 3.4726399999999997,
#    'soft_skills': 8.7676,
#    'untagged': 1.7948999999999997,
#    'total_time_on_resume': 28.960919999999998},
#   'UNQUALIFIED_NOPIC_BADSORT_TIAN.PNG': {'name': 3.8984400000000003,
#    'picture': 0,
#    'experience': 16.910120000000003,
#    'languages': 5.92184,
#    'education': 2.04686,
#    'skills': 1.9824199999999998,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 0.40234000000000003,
#    'total_time_on_resume': 31.16202000000001},
#   'UNQUALIFIED_NOPIC_ BADSORT_LEILA.PNG': {'name': 2.4941199999999997,
#    'picture': 0,
#    'experience': 36.589839999999995,
#    'languages': 3.03124,
#    'education': 4.2715,
#    'skills': 4.124999999999999,
#    'hobbies': 2.57226,
#    'soft_skills': 2.10352,
#    'untagged': 1.63282,
#    'total_time_on_resume': 56.82029999999999},
#   'QUALIFIED_PIC_ GOODSORT_HANNAH.PNG': {'name': 2.06248,
#    'picture': 0.71094,
#    'experience': 33.09574,
#    'languages': 2.6386600000000002,
#    'education': 6.138679999999999,
#    'skills': 1.81836,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 1.2031399999999999,
#    'total_time_on_resume': 47.66799999999996},
#   'QUALIFIED_PIC_ GOODSORT_AISHA.PNG': {'name': 0.33398,
#    'picture': 0.37500000000000006,
#    'experience': 14.923820000000003,
#    'languages': 4.982420000000001,
#    'education': 10.195299999999996,
#    'skills': 2.9726399999999997,
#    'hobbies': 5.880859999999999,
#    'soft_skills': 5.775379999999999,
#    'untagged': 1.2246000000000001,
#    'total_time_on_resume': 46.664000000000016},
#   'QUALIFIED_NOPIC_BADSORT_RAHUL.PNG': {'name': 1.66016,
#    'picture': 0,
#    'experience': 19.78903999999999,
#    'languages': 11.560580000000005,
#    'education': 0.8847799999999999,
#    'skills': 9.712860000000001,
#    'hobbies': 0,
#    'soft_skills': 0.45508,
#    'untagged': 2.39844,
#    'total_time_on_resume': 46.46093999999998},
#   'QUALIFIED_NOPIC_BADSORT_DAVID.PNG': {'name': 1.63868,
#    'picture': 0,
#    'experience': 30.75193999999999,
#    'languages': 0.16016,
#    'education': 6.74024,
#    'skills': 4.3144599999999995,
#    'hobbies': 0,
#    'soft_skills': 6.00392,
#    'untagged': 3.37498,
#    'total_time_on_resume': 52.984380000000016}},
#  {'QUALIFIED_NOPIC_GOODSORT_EMILIA.PNG': {'name': 0.2284,
#    'picture': 0,
#    'experience': 20.923839999999988,
#    'languages': 7.944979999999999,
#    'education': 7.38122,
#    'skills': 2.34702,
#    'hobbies': 0,
#    'soft_skills': 0.88434,
#    'untagged': 1.6073,
#    'total_time_on_resume': 41.31710000000002},
#   'QUALIFIED_NOPIC_BADSORT_VIKTOR.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 23.856940000000005,
#    'languages': 6.431280000000001,
#    'education': 4.382200000000001,
#    'skills': 4.8750800000000005,
#    'hobbies': 6.936580000000001,
#    'soft_skills': 5.505879999999999,
#    'untagged': 4.3612,
#    'total_time_on_resume': 56.34915999999999},
#   'UNQUALIFIED_PIC_GOODSORT_KARE.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 2.2911399999999995,
#    'languages': 0,
#    'education': 3.2422000000000004,
#    'skills': 0,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 2.78554,
#    'total_time_on_resume': 8.318879999999998},
#   'UNQUALIFIED_PIC_GOODSORT_HANS.PNG': {'name': 0,
#    'picture': 0.76374,
#    'experience': 3.30082,
#    'languages': 3.4694,
#    'education': 1.68792,
#    'skills': 0.54944,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 0,
#    'total_time_on_resume': 9.771320000000005},
#   'UNQUALIFIED_NOPIC_ BADSORT_MARIA.PNG': {'name': 0.20056,
#    'picture': 0,
#    'experience': 0.21424,
#    'languages': 0,
#    'education': 2.3316,
#    'skills': 0.90888,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 0.6969,
#    'total_time_on_resume': 4.35218},
#   'UNQUALIFIED_NOPIC_GOODSORT_LEA.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 9.217580000000002,
#    'languages': 0.69666,
#    'education': 0,
#    'skills': 0,
#    'hobbies': 4.353019999999999,
#    'soft_skills': 4.12648,
#    'untagged': 0.84412,
#    'total_time_on_resume': 19.237860000000005},
#   'UNQUALIFIED_NOPIC_BADSORT_TIAN.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 1.1255,
#    'languages': 3.14848,
#    'education': 0.72304,
#    'skills': 0.97742,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 2.2773399999999997,
#    'total_time_on_resume': 8.25178},
#   'UNQUALIFIED_PIC_ BADSORT_LEILA.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 0.33502,
#    'languages': 6.859299999999998,
#    'education': 0,
#    'skills': 0,
#    'hobbies': 0,
#    'soft_skills': 0.68226,
#    'untagged': 0.8844,
#    'total_time_on_resume': 8.760979999999998},
#   'QUALIFIED_PIC_ GOODSORT_HANNAH.PNG': {'name': 3.2962000000000002,
#    'picture': 0.38882,
#    'experience': 14.419579999999996,
#    'languages': 7.065419999999998,
#    'education': 8.5606,
#    'skills': 14.668480000000002,
#    'hobbies': 0,
#    'soft_skills': 1.46078,
#    'untagged': 0.38798,
#    'total_time_on_resume': 50.24786000000002},
#   'QUALIFIED_PIC_ GOODSORT_AISHA.PNG': {'name': 5.6388799999999994,
#    'picture': 0,
#    'experience': 10.152239999999997,
#    'languages': 0.4952,
#    'education': 1.7422,
#    'skills': 0.65652,
#    'hobbies': 7.7793600000000005,
#    'soft_skills': 8.40678,
#    'untagged': 0.50906,
#    'total_time_on_resume': 35.38023999999998},
#   'QUALIFIED_NOPIC_BADSORT_RAHUL.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 13.71862,
#    'languages': 2.4388,
#    'education': 10.86474,
#    'skills': 5.7469800000000015,
#    'hobbies': 0,
#    'soft_skills': 0.17414,
#    'untagged': 0.6969,
#    'total_time_on_resume': 33.64018000000001},
#   'QUALIFIED_PIC_BADSORT_DAVID.PNG': {'name': 0,
#    'picture': 4.7713,
#    'experience': 10.80798,
#    'languages': 2.3976600000000006,
#    'education': 6.06956,
#    'skills': 7.110540000000001,
#    'hobbies': 0,
#    'soft_skills': 3.512459999999999,
#    'untagged': 0.76312,
#    'total_time_on_resume': 35.43262000000002}},
#  {'QUALIFIED_NOPIC_GOODSORT_EMILIA.PNG': {'name': 5.4394800000000005,
#    'picture': 0,
#    'experience': 11.199199999999998,
#    'languages': 3.011699999999999,
#    'education': 4.900339999999999,
#    'skills': 9.029279999999998,
#    'hobbies': 2.00976,
#    'soft_skills': 0.52148,
#    'untagged': 1.11132,
#    'total_time_on_resume': 37.22256000000002},
#   'QUALIFIED_NOPIC_BADSORT_VIKTOR.PNG': {'name': 1.7949199999999998,
#    'picture': 0,
#    'experience': 17.302719999999994,
#    'languages': 4.68556,
#    'education': 2.1445399999999997,
#    'skills': 7.529280000000002,
#    'hobbies': 1.64842,
#    'soft_skills': 7.084000000000001,
#    'untagged': 0.8300800000000002,
#    'total_time_on_resume': 43.019520000000014},
#   'UNQUALIFIED_NOPIC_GOODSORT_KARE.PNG': {'name': 1.16602,
#    'picture': 0,
#    'experience': 1.51172,
#    'languages': 3.13282,
#    'education': 2.33202,
#    'skills': 2.04688,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 7.302720000000001,
#    'total_time_on_resume': 17.49217999999999},
#   'UNQUALIFIED_PIC_GOODSORT_HANS.PNG': {'name': 2.69336,
#    'picture': 1.44728,
#    'experience': 9.457099999999997,
#    'languages': 2.85158,
#    'education': 7.19334,
#    'skills': 2.04882,
#    'hobbies': 1.16798,
#    'soft_skills': 2.00782,
#    'untagged': 0.52344,
#    'total_time_on_resume': 29.390719999999988},
#   'UNQUALIFIED_NOPIC_ BADSORT_MARIA.PNG': {'name': 9.201199999999998,
#    'picture': 0,
#    'experience': 4.49024,
#    'languages': 0,
#    'education': 4.412119999999999,
#    'skills': 2.7461,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 1.6757799999999998,
#    'total_time_on_resume': 22.525439999999993},
#   'UNQUALIFIED_PIC_GOODSORT_LEA.PNG': {'name': 2.14452,
#    'picture': 3.1601399999999997,
#    'experience': 9.80666,
#    'languages': 2.34376,
#    'education': 1.29882,
#    'skills': 0.9921800000000001,
#    'hobbies': 8.02734,
#    'soft_skills': 4.01954,
#    'untagged': 1.0976599999999999,
#    'total_time_on_resume': 32.890620000000006},
#   'UNQUALIFIED_PIC_BADSORT_TIAN.PNG': {'name': 2.8535200000000005,
#    'picture': 2.2636600000000002,
#    'experience': 5.205100000000001,
#    'languages': 12.326180000000003,
#    'education': 3.11914,
#    'skills': 3.96288,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 1.4374600000000002,
#    'total_time_on_resume': 31.167939999999994},
#   'UNQUALIFIED_NOPIC_ BADSORT_LEILA.PNG': {'name': 3.86328,
#    'picture': 0,
#    'experience': 4.2461,
#    'languages': 3.64648,
#    'education': 2.96094,
#    'skills': 2.4003599999999996,
#    'hobbies': 1.59374,
#    'soft_skills': 1.9570199999999998,
#    'untagged': 0.22656,
#    'total_time_on_resume': 20.894480000000005},
#   'QUALIFIED_PIC_ GOODSORT_HANNAH.PNG': {'name': 1.9296799999999998,
#    'picture': 1.17772,
#    'experience': 18.914019999999997,
#    'languages': 6.566380000000003,
#    'education': 7.214820000000002,
#    'skills': 10.005859999999997,
#    'hobbies': 0,
#    'soft_skills': 0.88476,
#    'untagged': 0.68164,
#    'total_time_on_resume': 47.37488},
#   'QUALIFIED_NOPIC_ GOODSORT_AISHA.PNG': {'name': 5.31446,
#    'picture': 0,
#    'experience': 8.36522,
#    'languages': 2.26562,
#    'education': 5.492180000000001,
#    'skills': 2.6913799999999997,
#    'hobbies': 7.664040000000001,
#    'soft_skills': 3.6972800000000006,
#    'untagged': 4.611320000000001,
#    'total_time_on_resume': 40.10149999999999},
#   'QUALIFIED_PIC_BADSORT_RAHUL.PNG': {'name': 2.1426000000000003,
#    'picture': 0.76368,
#    'experience': 24.326100000000004,
#    'languages': 7.087859999999999,
#    'education': 9.802759999999994,
#    'skills': 3.2539000000000007,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 0.16016,
#    'total_time_on_resume': 47.53706000000002},
#   'QUALIFIED_PIC_BADSORT_DAVID.PNG': {'name': 1.23242,
#    'picture': 2.3047,
#    'experience': 14.734460000000002,
#    'languages': 5.921859999999999,
#    'education': 4.6465000000000005,
#    'skills': 4.44922,
#    'hobbies': 0,
#    'soft_skills': 12.408199999999999,
#    'untagged': 0,
#    'total_time_on_resume': 45.69735999999997}},
#  {'QUALIFIED_PIC_GOODSORT_EMILIA.PNG': {'name': 0,
#    'picture': 0.54992,
#    'experience': 18.234379999999998,
#    'languages': 4.27098,
#    'education': 2.8402599999999993,
#    'skills': 2.3055,
#    'hobbies': 1.09894,
#    'soft_skills': 2.21026,
#    'untagged': 0,
#    'total_time_on_resume': 31.510240000000003},
#   'QUALIFIED_NOPIC_BADSORT_VIKTOR.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 24.9968,
#    'languages': 4.87606,
#    'education': 3.16218,
#    'skills': 2.9068400000000003,
#    'hobbies': 0.37512,
#    'soft_skills': 1.5274,
#    'untagged': 0,
#    'total_time_on_resume': 37.844399999999986},
#   'UNQUALIFIED_NOPIC_GOODSORT_KARE.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 2.31794,
#    'languages': 2.29138,
#    'education': 0,
#    'skills': 5.305300000000001,
#    'hobbies': 0.79016,
#    'soft_skills': 0,
#    'untagged': 1.7279799999999998,
#    'total_time_on_resume': 12.432759999999998},
#   'UNQUALIFIED_PIC_GOODSORT_HANS.PNG': {'name': 0.22778,
#    'picture': 0.72332,
#    'experience': 9.3245,
#    'languages': 6.36326,
#    'education': 4.2735199999999995,
#    'skills': 11.573719999999998,
#    'hobbies': 2.8277,
#    'soft_skills': 3.95208,
#    'untagged': 0,
#    'total_time_on_resume': 39.26588},
#   'UNQUALIFIED_PIC_ BADSORT_MARIA.PNG': {'name': 1.74254,
#    'picture': 0.844,
#    'experience': 2.78722,
#    'languages': 0.45556,
#    'education': 3.76478,
#    'skills': 3.8985600000000002,
#    'hobbies': 1.3533999999999997,
#    'soft_skills': 0,
#    'untagged': 0.36194,
#    'total_time_on_resume': 15.208},
#   'UNQUALIFIED_NOPIC_GOODSORT_LEA.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 15.25948,
#    'languages': 1.44616,
#    'education': 2.0097199999999997,
#    'skills': 4.68816,
#    'hobbies': 6.791059999999999,
#    'soft_skills': 2.72064,
#    'untagged': 0,
#    'total_time_on_resume': 32.91522},
#   'UNQUALIFIED_NOPIC_BADSORT_TIAN.PNG': {'name': 0.25416,
#    'picture': 0,
#    'experience': 4.581279999999999,
#    'languages': 2.9873,
#    'education': 1.32634,
#    'skills': 2.26484,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 0.05346,
#    'total_time_on_resume': 11.46738},
#   'UNQUALIFIED_PIC_ BADSORT_LEILA.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 5.397079999999999,
#    'languages': 3.0414399999999997,
#    'education': 1.94188,
#    'skills': 0.8566199999999999,
#    'hobbies': 0.6297,
#    'soft_skills': 0.65606,
#    'untagged': 0,
#    'total_time_on_resume': 12.52278},
#   'QUALIFIED_PIC_ GOODSORT_HANNAH.PNG': {'name': 0.32172,
#    'picture': 0.8035,
#    'experience': 39.65090000000002,
#    'languages': 2.8273000000000006,
#    'education': 12.58452,
#    'skills': 5.3052199999999985,
#    'hobbies': 0,
#    'soft_skills': 0.71006,
#    'untagged': 1.78116,
#    'total_time_on_resume': 63.98437999999999},
#   'QUALIFIED_NOPIC_ GOODSORT_AISHA.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 21.923980000000007,
#    'languages': 2.31806,
#    'education': 5.251759999999999,
#    'skills': 1.2727,
#    'hobbies': 5.1709000000000005,
#    'soft_skills': 2.73188,
#    'untagged': 0.52296,
#    'total_time_on_resume': 39.192239999999984},
#   'QUALIFIED_PIC_BADSORT_RAHUL.PNG': {'name': 0,
#    'picture': 0.93782,
#    'experience': 18.859759999999998,
#    'languages': 20.53818,
#    'education': 4.23362,
#    'skills': 1.1657,
#    'hobbies': 0,
#    'soft_skills': 3.9120999999999997,
#    'untagged': 0,
#    'total_time_on_resume': 49.64718},
#   'QUALIFIED_NOPIC_BADSORT_DAVID.PNG': {'name': 0.14728,
#    'picture': 0,
#    'experience': 22.22508,
#    'languages': 4.461239999999999,
#    'education': 4.12702,
#    'skills': 5.359399999999999,
#    'hobbies': 0,
#    'soft_skills': 6.070059999999999,
#    'untagged': 0,
#    'total_time_on_resume': 42.390080000000005}},
#  {'QUALIFIED_NOPIC_GOODSORT_EMILIA.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 61.12018000000003,
#    'languages': 2.89356,
#    'education': 4.019779999999999,
#    'skills': 7.63526,
#    'hobbies': 0.5227,
#    'soft_skills': 1.32616,
#    'untagged': 1.19238,
#    'total_time_on_resume': 78.71002000000007},
#   'QUALIFIED_NOPIC_BADSORT_VIKTOR.PNG': {'name': 1.2458399999999998,
#    'picture': 0,
#    'experience': 56.66276000000001,
#    'languages': 4.4065199999999995,
#    'education': 1.68798,
#    'skills': 8.452139999999998,
#    'hobbies': 0.73706,
#    'soft_skills': 0.79078,
#    'untagged': 0.80446,
#    'total_time_on_resume': 74.78754},
#   'UNQUALIFIED_PIC_GOODSORT_KARE.PNG': {'name': 0.8969800000000001,
#    'picture': 0,
#    'experience': 3.6833600000000004,
#    'languages': 6.95264,
#    'education': 0.72242,
#    'skills': 8.01074,
#    'hobbies': 0.4956,
#    'soft_skills': 0,
#    'untagged': 3.2817400000000005,
#    'total_time_on_resume': 24.043480000000002},
#   'UNQUALIFIED_NOPIC_GOODSORT_HANS.PNG': {'name': 0.26732,
#    'picture': 0,
#    'experience': 28.532999999999994,
#    'languages': 1.28564,
#    'education': 13.033939999999998,
#    'skills': 2.07592,
#    'hobbies': 1.2328999999999999,
#    'soft_skills': 1.8884400000000001,
#    'untagged': 0,
#    'total_time_on_resume': 48.31716},
#   'UNQUALIFIED_PIC_ BADSORT_MARIA.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 4.099139999999999,
#    'languages': 0.91138,
#    'education': 3.7771,
#    'skills': 4.8225,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 0.79004,
#    'total_time_on_resume': 14.400160000000001},
#   'UNQUALIFIED_PIC_GOODSORT_LEA.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 6.216060000000002,
#    'languages': 0.57544,
#    'education': 0.89746,
#    'skills': 4.10084,
#    'hobbies': 14.040579999999993,
#    'soft_skills': 11.435819999999998,
#    'untagged': 0.21436,
#    'total_time_on_resume': 37.480559999999976},
#   'UNQUALIFIED_NOPIC_BADSORT_TIAN.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 7.917239999999998,
#    'languages': 2.26442,
#    'education': 0.75098,
#    'skills': 2.3977000000000004,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 0,
#    'total_time_on_resume': 13.33034},
#   'UNQUALIFIED_NOPIC_ BADSORT_LEILA.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 1.25976,
#    'languages': 2.8671800000000003,
#    'education': 0,
#    'skills': 0,
#    'hobbies': 0.29444,
#    'soft_skills': 0.26832,
#    'untagged': 0,
#    'total_time_on_resume': 4.6897},
#   'QUALIFIED_PIC_ GOODSORT_HANNAH.PNG': {'name': 1.3527799999999996,
#    'picture': 0,
#    'experience': 52.29079999999996,
#    'languages': 3.68504,
#    'education': 10.088679999999997,
#    'skills': 2.3300799999999997,
#    'hobbies': 0,
#    'soft_skills': 1.0852,
#    'untagged': 1.0442,
#    'total_time_on_resume': 71.87678000000002},
#   'QUALIFIED_PIC_ GOODSORT_AISHA.PNG': {'name': 0.96458,
#    'picture': 0,
#    'experience': 52.38982000000003,
#    'languages': 2.0366199999999997,
#    'education': 6.056139999999999,
#    'skills': 3.96484,
#    'hobbies': 17.86668,
#    'soft_skills': 3.59034,
#    'untagged': 0.5358999999999999,
#    'total_time_on_resume': 87.4049199999999},
#   'QUALIFIED_PIC_BADSORT_RAHUL.PNG': {'name': 1.2417,
#    'picture': 0,
#    'experience': 17.538520000000002,
#    'languages': 40.97216,
#    'education': 10.380140000000003,
#    'skills': 6.135019999999999,
#    'hobbies': 0,
#    'soft_skills': 7.996839999999999,
#    'untagged': 2.8535199999999996,
#    'total_time_on_resume': 87.11789999999996},
#   'QUALIFIED_NOPIC_BADSORT_DAVID.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 43.5569,
#    'languages': 1.2724600000000001,
#    'education': 1.5034199999999998,
#    'skills': 2.4231,
#    'hobbies': 0,
#    'soft_skills': 1.25074,
#    'untagged': 0,
#    'total_time_on_resume': 50.00662}},
#  {'QUALIFIED_PIC_GOODSORT_EMILIA.PNG': {'name': 0.4961,
#    'picture': 1.03126,
#    'experience': 37.61912,
#    'languages': 1.76612,
#    'education': 2.8120200000000004,
#    'skills': 1.40722,
#    'hobbies': 0,
#    'soft_skills': 0.64306,
#    'untagged': 5.812060000000001,
#    'total_time_on_resume': 51.586960000000005},
#   'QUALIFIED_PIC_BADSORT_VIKTOR.PNG': {'name': 2.05322,
#    'picture': 0.64208,
#    'experience': 16.01656000000001,
#    'languages': 6.93992,
#    'education': 2.03564,
#    'skills': 4.540560000000001,
#    'hobbies': 0,
#    'soft_skills': 5.15574,
#    'untagged': 2.119159999999999,
#    'total_time_on_resume': 39.50288000000002},
#   'UNQUALIFIED_NOPIC_GOODSORT_KARE.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 5.223579999999998,
#    'languages': 2.800960000000001,
#    'education': 0.8010799999999999,
#    'skills': 2.96148,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 0.81226,
#    'total_time_on_resume': 12.599359999999999},
#   'UNQUALIFIED_PIC_GOODSORT_HANS.PNG': {'name': 0,
#    'picture': 0.66992,
#    'experience': 29.012559999999972,
#    'languages': 1.27276,
#    'education': 6.32446,
#    'skills': 3.14844,
#    'hobbies': 1.04498,
#    'soft_skills': 1.03136,
#    'untagged': 0,
#    'total_time_on_resume': 42.50447999999998},
#   'UNQUALIFIED_PIC_ BADSORT_MARIA.PNG': {'name': 1.3667,
#    'picture': 0.48242,
#    'experience': 8.018660000000002,
#    'languages': 0.38868,
#    'education': 0.46837999999999996,
#    'skills': 4.995999999999999,
#    'hobbies': 1.62072,
#    'soft_skills': 0,
#    'untagged': 0,
#    'total_time_on_resume': 17.34155999999999},
#   'UNQUALIFIED_PIC_GOODSORT_LEA.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 12.684340000000004,
#    'languages': 0.83008,
#    'education': 1.313,
#    'skills': 0.8177599999999999,
#    'hobbies': 2.9347000000000003,
#    'soft_skills': 3.0688199999999997,
#    'untagged': 0.41498,
#    'total_time_on_resume': 22.06368},
#   'UNQUALIFIED_NOPIC_BADSORT_TIAN.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 9.641299999999998,
#    'languages': 2.65264,
#    'education': 1.0316800000000002,
#    'skills': 2.62634,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 0,
#    'total_time_on_resume': 15.95196},
#   'UNQUALIFIED_NOPIC_ BADSORT_LEILA.PNG': {'name': 1.67492,
#    'picture': 0,
#    'experience': 20.20248000000001,
#    'languages': 1.20288,
#    'education': 1.88904,
#    'skills': 4.60054,
#    'hobbies': 1.6745,
#    'soft_skills': 6.250279999999999,
#    'untagged': 0.7637800000000001,
#    'total_time_on_resume': 38.25842000000001},
#   'QUALIFIED_NOPIC_ GOODSORT_HANNAH.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 20.964420000000008,
#    'languages': 6.309840000000001,
#    'education': 5.54546,
#    'skills': 1.45556,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 0,
#    'total_time_on_resume': 34.275279999999995},
#   'QUALIFIED_NOPIC_ GOODSORT_AISHA.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 23.17134,
#    'languages': 1.66284,
#    'education': 2.02276,
#    'skills': 6.5774,
#    'hobbies': 2.23596,
#    'soft_skills': 2.7502000000000004,
#    'untagged': 1.1529399999999999,
#    'total_time_on_resume': 39.573440000000005},
#   'QUALIFIED_NOPIC_BADSORT_RAHUL.PNG': {'name': 1.60874,
#    'picture': 0,
#    'experience': 15.298659999999995,
#    'languages': 9.590119999999999,
#    'education': 2.34486,
#    'skills': 3.49646,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 2.27776,
#    'total_time_on_resume': 34.61659999999998},
#   'QUALIFIED_PIC_BADSORT_DAVID.PNG': {'name': 0.24122,
#    'picture': 0.4956,
#    'experience': 25.667999999999985,
#    'languages': 4.837899999999999,
#    'education': 2.3457000000000003,
#    'skills': 8.742619999999999,
#    'hobbies': 0,
#    'soft_skills': 3.246079999999999,
#    'untagged': 3.8344400000000003,
#    'total_time_on_resume': 49.411559999999966}},
#  {'QUALIFIED_PIC_GOODSORT_EMILIA.PNG': {'name': 3.3350999999999997,
#    'picture': 1.3543,
#    'experience': 34.72638000000003,
#    'languages': 5.3049,
#    'education': 6.793260000000001,
#    'skills': 1.13916,
#    'hobbies': 0,
#    'soft_skills': 1.07212,
#    'untagged': 0,
#    'total_time_on_resume': 53.725220000000036},
#   'QUALIFIED_NOPIC_BADSORT_VIKTOR.PNG': {'name': 3.05492,
#    'picture': 0,
#    'experience': 42.67420000000007,
#    'languages': 4.969999999999999,
#    'education': 2.39848,
#    'skills': 8.439160000000001,
#    'hobbies': 3.09484,
#    'soft_skills': 3.8823600000000003,
#    'untagged': 0.3345,
#    'total_time_on_resume': 68.84845999999999},
#   'UNQUALIFIED_PIC_GOODSORT_KARE.PNG': {'name': 0.32136,
#    'picture': 0.18756,
#    'experience': 7.4219599999999994,
#    'languages': 0.56292,
#    'education': 1.2323,
#    'skills': 0,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 2.3841599999999996,
#    'total_time_on_resume': 12.11026},
#   'UNQUALIFIED_NOPIC_GOODSORT_HANS.PNG': {'name': 2.2497599999999998,
#    'picture': 0,
#    'experience': 29.81238000000002,
#    'languages': 2.58514,
#    'education': 18.630240000000004,
#    'skills': 6.939700000000001,
#    'hobbies': 7.851,
#    'soft_skills': 34.173039999999986,
#    'untagged': 0.3615,
#    'total_time_on_resume': 102.60275999999992},
#   'UNQUALIFIED_PIC_ BADSORT_MARIA.PNG': {'name': 1.1652799999999999,
#    'picture': 0.8980199999999999,
#    'experience': 4.032280000000001,
#    'languages': 0.83038,
#    'education': 2.89434,
#    'skills': 3.6962200000000003,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 0.30779999999999996,
#    'total_time_on_resume': 13.824319999999997},
#   'UNQUALIFIED_NOPIC_GOODSORT_LEA.PNG': {'name': 1.35334,
#    'picture': 0,
#    'experience': 11.118780000000001,
#    'languages': 0.60328,
#    'education': 0.17382,
#    'skills': 0,
#    'hobbies': 4.676679999999999,
#    'soft_skills': 4.91702,
#    'untagged': 0.8031,
#    'total_time_on_resume': 23.646019999999993},
#   'UNQUALIFIED_PIC_BADSORT_TIAN.PNG': {'name': 0.40186,
#    'picture': 0.5498000000000001,
#    'experience': 10.315660000000001,
#    'languages': 3.2159600000000004,
#    'education': 3.2952399999999997,
#    'skills': 0,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 0,
#    'total_time_on_resume': 17.778519999999997},
#   'UNQUALIFIED_NOPIC_ BADSORT_LEILA.PNG': {'name': 1.39278,
#    'picture': 0,
#    'experience': 3.4013800000000005,
#    'languages': 2.9742600000000006,
#    'education': 0,
#    'skills': 0,
#    'hobbies': 1.29894,
#    'soft_skills': 0.6565,
#    'untagged': 0,
#    'total_time_on_resume': 9.723859999999998},
#   'QUALIFIED_PIC_ GOODSORT_HANNAH.PNG': {'name': 7.107860000000002,
#    'picture': 1.1519000000000001,
#    'experience': 44.96089999999998,
#    'languages': 5.31404,
#    'education': 14.574119999999999,
#    'skills': 5.0769,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 2.3584800000000006,
#    'total_time_on_resume': 80.54419999999995},
#   'QUALIFIED_PIC_ GOODSORT_AISHA.PNG': {'name': 5.62098,
#    'picture': 0.5484,
#    'experience': 20.943600000000007,
#    'languages': 6.1637,
#    'education': 7.166160000000001,
#    'skills': 3.38262,
#    'hobbies': 11.025299999999996,
#    'soft_skills': 7.7911600000000005,
#    'untagged': 2.7325,
#    'total_time_on_resume': 65.37442000000001},
#   'QUALIFIED_NOPIC_BADSORT_RAHUL.PNG': {'name': 2.5991800000000005,
#    'picture': 0,
#    'experience': 15.942740000000008,
#    'languages': 16.447460000000003,
#    'education': 6.2605200000000005,
#    'skills': 3.3367200000000006,
#    'hobbies': 0,
#    'soft_skills': 4.04604,
#    'untagged': 1.50598,
#    'total_time_on_resume': 50.13863999999999},
#   'QUALIFIED_NOPIC_BADSORT_DAVID.PNG': {'name': 1.19324,
#    'picture': 0,
#    'experience': 45.04910000000005,
#    'languages': 10.047320000000001,
#    'education': 5.640159999999999,
#    'skills': 4.25976,
#    'hobbies': 0,
#    'soft_skills': 2.62584,
#    'untagged': 2.6525399999999997,
#    'total_time_on_resume': 71.46795999999993}},
#  {'QUALIFIED_PIC_GOODSORT_EMILIA.PNG': {'name': 6.82936,
#    'picture': 2.0309,
#    'experience': 75.41718000000009,
#    'languages': 5.493859999999999,
#    'education': 3.6450200000000006,
#    'skills': 0.4956,
#    'hobbies': 1.3111599999999999,
#    'soft_skills': 0.1294,
#    'untagged': 2.1924,
#    'total_time_on_resume': 97.54488000000006},
#   'QUALIFIED_NOPIC_BADSORT_VIKTOR.PNG': {'name': 4.966900000000001,
#    'picture': 0,
#    'experience': 74.35834000000001,
#    'languages': 4.5594600000000005,
#    'education': 8.02454,
#    'skills': 6.5911800000000005,
#    'hobbies': 8.82484,
#    'soft_skills': 30.057579999999994,
#    'untagged': 2.4641199999999994,
#    'total_time_on_resume': 139.84695999999994},
#   'UNQUALIFIED_PIC_GOODSORT_KARE.PNG': {'name': 0,
#    'picture': 0.56324,
#    'experience': 6.5327,
#    'languages': 0,
#    'education': 1.3256800000000002,
#    'skills': 0.75,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 0.25464,
#    'total_time_on_resume': 9.426259999999994},
#   'UNQUALIFIED_NOPIC_GOODSORT_HANS.PNG': {'name': 0.58936,
#    'picture': 0,
#    'experience': 20.64526,
#    'languages': 9.721440000000001,
#    'education': 17.782739999999997,
#    'skills': 4.22068,
#    'hobbies': 4.393040000000001,
#    'soft_skills': 8.895259999999999,
#    'untagged': 2.23924,
#    'total_time_on_resume': 68.48701999999997},
#   'UNQUALIFIED_PIC_ BADSORT_MARIA.PNG': {'name': 0,
#    'picture': 0.60254,
#    'experience': 19.334180000000003,
#    'languages': 1.87548,
#    'education': 1.2988400000000002,
#    'skills': 1.9970800000000002,
#    'hobbies': 0.9543600000000001,
#    'soft_skills': 0,
#    'untagged': 0.52172,
#    'total_time_on_resume': 26.584200000000017},
#   'UNQUALIFIED_PIC_GOODSORT_LEA.PNG': {'name': 0.89722,
#    'picture': 0,
#    'experience': 7.124779999999996,
#    'languages': 0.8173799999999999,
#    'education': 0,
#    'skills': 0,
#    'hobbies': 3.6984800000000004,
#    'soft_skills': 3.7920000000000003,
#    'untagged': 0,
#    'total_time_on_resume': 16.329859999999996},
#   'UNQUALIFIED_NOPIC_BADSORT_TIAN.PNG': {'name': 3.0522400000000003,
#    'picture': 0,
#    'experience': 1.1626,
#    'languages': 8.52882,
#    'education': 2.29076,
#    'skills': 7.001480000000002,
#    'hobbies': 0,
#    'soft_skills': 0.1609,
#    'untagged': 0.85718,
#    'total_time_on_resume': 23.053979999999996},
#   'UNQUALIFIED_NOPIC_ BADSORT_LEILA.PNG': {'name': 4.33008,
#    'picture': 0,
#    'experience': 4.54074,
#    'languages': 6.85672,
#    'education': 2.0586,
#    'skills': 4.541499999999999,
#    'hobbies': 7.489479999999999,
#    'soft_skills': 11.10894,
#    'untagged': 3.0129399999999995,
#    'total_time_on_resume': 43.93900000000001},
#   'QUALIFIED_NOPIC_ GOODSORT_HANNAH.PNG': {'name': 1.4868199999999998,
#    'picture': 0,
#    'experience': 23.741160000000008,
#    'languages': 8.076439999999998,
#    'education': 3.7792999999999997,
#    'skills': 2.5190400000000004,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 0,
#    'total_time_on_resume': 39.60276},
#   'QUALIFIED_PIC_ GOODSORT_AISHA.PNG': {'name': 3.65002,
#    'picture': 1.1927599999999998,
#    'experience': 29.81603999999999,
#    'languages': 3.5451799999999993,
#    'education': 11.77686,
#    'skills': 5.04982,
#    'hobbies': 13.094219999999993,
#    'soft_skills': 5.13074,
#    'untagged': 1.6159599999999998,
#    'total_time_on_resume': 74.87160000000006},
#   'QUALIFIED_PIC_BADSORT_RAHUL.PNG': {'name': 1.36668,
#    'picture': 0.30786,
#    'experience': 21.809780000000007,
#    'languages': 17.31992,
#    'education': 11.702259999999997,
#    'skills': 2.1034,
#    'hobbies': 0,
#    'soft_skills': 1.50966,
#    'untagged': 1.4326000000000005,
#    'total_time_on_resume': 57.55216},
#   'QUALIFIED_NOPIC_BADSORT_DAVID.PNG': {'name': 2.8730800000000007,
#    'picture': 0,
#    'experience': 47.2437,
#    'languages': 3.0146600000000006,
#    'education': 8.75342,
#    'skills': 9.47316,
#    'hobbies': 0,
#    'soft_skills': 18.739980000000003,
#    'untagged': 0.5227,
#    'total_time_on_resume': 90.62069999999994}},
#  {'QUALIFIED_PIC_GOODSORT_EMILIA.PNG': {'name': 0.36176,
#    'picture': 0,
#    'experience': 10.475160000000004,
#    'languages': 2.4923799999999994,
#    'education': 3.4428,
#    'skills': 0,
#    'hobbies': 0,
#    'soft_skills': 0.56308,
#    'untagged': 0,
#    'total_time_on_resume': 17.33518},
#   'QUALIFIED_PIC_BADSORT_VIKTOR.PNG': {'name': 3.14804,
#    'picture': 0.72332,
#    'experience': 17.090119999999988,
#    'languages': 3.4838199999999993,
#    'education': 2.55954,
#    'skills': 5.732420000000001,
#    'hobbies': 3.7368200000000003,
#    'soft_skills': 0.9224199999999999,
#    'untagged': 1.5724,
#    'total_time_on_resume': 38.96889999999997},
#   'UNQUALIFIED_PIC_GOODSORT_KARE.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 0.9646399999999999,
#    'languages': 0,
#    'education': 0.9104399999999999,
#    'skills': 1.6474,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 1.42036,
#    'total_time_on_resume': 4.94284},
#   'UNQUALIFIED_NOPIC_GOODSORT_HANS.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 0,
#    'languages': 0.57576,
#    'education': 0,
#    'skills': 2.5987,
#    'hobbies': 0,
#    'soft_skills': 2.03668,
#    'untagged': 0,
#    'total_time_on_resume': 5.21114},
#   'UNQUALIFIED_PIC_ BADSORT_MARIA.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 0.2685,
#    'languages': 0,
#    'education': 0.5491999999999999,
#    'skills': 2.6485,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 0,
#    'total_time_on_resume': 3.4662000000000006},
#   'UNQUALIFIED_NOPIC_GOODSORT_LEA.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 4.48538,
#    'languages': 0.70996,
#    'education': 0,
#    'skills': 0.36194,
#    'hobbies': 2.6513799999999996,
#    'soft_skills': 1.8066400000000002,
#    'untagged': 0.5097,
#    'total_time_on_resume': 10.525000000000002},
#   'UNQUALIFIED_NOPIC_BADSORT_TIAN.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 5.252080000000001,
#    'languages': 3.6713200000000006,
#    'education': 0.2406,
#    'skills': 0,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 0,
#    'total_time_on_resume': 9.164000000000007},
#   'UNQUALIFIED_PIC_ BADSORT_LEILA.PNG': {'name': 0,
#    'picture': 0.17376,
#    'experience': 3.54982,
#    'languages': 1.34032,
#    'education': 0,
#    'skills': 0.26806,
#    'hobbies': 0,
#    'soft_skills': 0.79004,
#    'untagged': 0.3617,
#    'total_time_on_resume': 6.4837},
#   'QUALIFIED_PIC_ GOODSORT_HANNAH.PNG': {'name': 0.57662,
#    'picture': 0,
#    'experience': 7.434819999999998,
#    'languages': 3.7633999999999994,
#    'education': 5.774279999999998,
#    'skills': 7.702619999999999,
#    'hobbies': 0,
#    'soft_skills': 1.1386800000000001,
#    'untagged': 1.0717999999999999,
#    'total_time_on_resume': 27.462220000000016},
#   'QUALIFIED_NOPIC_ GOODSORT_AISHA.PNG': {'name': 0.81696,
#    'picture': 0,
#    'experience': 4.95582,
#    'languages': 4.354520000000001,
#    'education': 0,
#    'skills': 3.3762999999999996,
#    'hobbies': 3.6839999999999997,
#    'soft_skills': 3.1353399999999993,
#    'untagged': 0,
#    'total_time_on_resume': 20.32294},
#   'QUALIFIED_NOPIC_BADSORT_DAVID.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 9.740279999999998,
#    'languages': 2.2636600000000002,
#    'education': 4.073459999999999,
#    'skills': 2.0362,
#    'hobbies': 0,
#    'soft_skills': 0.74816,
#    'untagged': 0,
#    'total_time_on_resume': 18.861759999999997}},
#  {'QUALIFIED_PIC_GOODSORT_EMILIA.PNG': {'name': 0.79054,
#    'picture': 0,
#    'experience': 12.52226,
#    'languages': 3.4032999999999993,
#    'education': 3.04028,
#    'skills': 0.4956,
#    'hobbies': 0,
#    'soft_skills': 2.03612,
#    'untagged': 0.32154,
#    'total_time_on_resume': 22.609640000000002},
#   'QUALIFIED_PIC_BADSORT_VIKTOR.PNG': {'name': 2.13112,
#    'picture': 0,
#    'experience': 12.872799999999998,
#    'languages': 3.6970400000000003,
#    'education': 4.703380000000001,
#    'skills': 7.581299999999998,
#    'hobbies': 3.28172,
#    'soft_skills': 11.400619999999996,
#    'untagged': 0,
#    'total_time_on_resume': 45.66797999999997},
#   'UNQUALIFIED_PIC_GOODSORT_KARE.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 5.58596,
#    'languages': 7.3134999999999994,
#    'education': 4.8367200000000015,
#    'skills': 0,
#    'hobbies': 3.92406,
#    'soft_skills': 0,
#    'untagged': 5.640139999999999,
#    'total_time_on_resume': 27.300380000000025},
#   'UNQUALIFIED_PIC_GOODSORT_HANS.PNG': {'name': 0,
#    'picture': 0.88428,
#    'experience': 6.632079999999999,
#    'languages': 2.7595399999999994,
#    'education': 4.43432,
#    'skills': 2.07642,
#    'hobbies': 1.8217999999999999,
#    'soft_skills': 2.29076,
#    'untagged': 0.49584,
#    'total_time_on_resume': 21.39504},
#   'UNQUALIFIED_NOPIC_ BADSORT_MARIA.PNG': {'name': 1.08522,
#    'picture': 0,
#    'experience': 4.0718000000000005,
#    'languages': 0,
#    'education': 3.30862,
#    'skills': 1.99512,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 0,
#    'total_time_on_resume': 10.460760000000006},
#   'UNQUALIFIED_PIC_GOODSORT_LEA.PNG': {'name': 2.3579200000000005,
#    'picture': 0.79054,
#    'experience': 12.861780000000001,
#    'languages': 1.39428,
#    'education': 4.970939999999999,
#    'skills': 0,
#    'hobbies': 8.59934,
#    'soft_skills': 1.78172,
#    'untagged': 1.5009800000000002,
#    'total_time_on_resume': 34.257500000000014},
#   'UNQUALIFIED_NOPIC_BADSORT_TIAN.PNG': {'name': 1.27222,
#    'picture': 0,
#    'experience': 7.03152,
#    'languages': 5.37252,
#    'education': 2.57104,
#    'skills': 3.1874999999999996,
#    'hobbies': 0,
#    'soft_skills': 0,
#    'untagged': 0,
#    'total_time_on_resume': 19.434800000000003},
#   'UNQUALIFIED_NOPIC_ BADSORT_LEILA.PNG': {'name': 1.03224,
#    'picture': 0,
#    'experience': 6.0398,
#    'languages': 2.7861400000000005,
#    'education': 4.05834,
#    'skills': 0.56274,
#    'hobbies': 2.08936,
#    'soft_skills': 0.36158,
#    'untagged': 0.70998,
#    'total_time_on_resume': 17.640180000000004},
#   'QUALIFIED_NOPIC_ GOODSORT_HANNAH.PNG': {'name': 1.9157599999999997,
#    'picture': 0,
#    'experience': 21.620860000000004,
#    'languages': 4.7812399999999995,
#    'education': 6.1880000000000015,
#    'skills': 5.11012,
#    'hobbies': 0,
#    'soft_skills': 1.79492,
#    'untagged': 0,
#    'total_time_on_resume': 41.41089999999997},
#   'QUALIFIED_PIC_ GOODSORT_AISHA.PNG': {'name': 2.02296,
#    'picture': 0.64282,
#    'experience': 3.6967800000000004,
#    'languages': 4.354979999999999,
#    'education': 4.07276,
#    'skills': 2.58398,
#    'hobbies': 3.8728000000000007,
#    'soft_skills': 5.854499999999999,
#    'untagged': 0.50952,
#    'total_time_on_resume': 27.611100000000008},
#   'QUALIFIED_NOPIC_BADSORT_RAHUL.PNG': {'name': 0,
#    'picture': 0,
#    'experience': 18.954780000000003,
#    'languages': 14.19918,
#    'education': 6.563239999999999,
#    'skills': 1.74146,
#    'hobbies': 0,
#    'soft_skills': 3.2685200000000005,
#    'untagged': 1.2036200000000001,
#    'total_time_on_resume': 45.9308},
#   'QUALIFIED_NOPIC_BADSORT_DAVID.PNG': {'name': 4.15382,
#    'picture': 0,
#    'experience': 42.25370000000002,
#    'languages': 3.72412,
#    'education': 6.819099999999999,
#    'skills': 3.148180000000001,
#    'hobbies': 0,
#    'soft_skills': 10.0071,
#    'untagged': 0.75098,
#    'total_time_on_resume': 70.85699999999996}}]
